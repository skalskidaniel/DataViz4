# %% [markdown]
# # Interactive dashboard for alcohol reviewer/picker
# ## Import

# %%
import kagglehub
import pandas as pd
import os

dataset_path = kagglehub.dataset_download("limtis/wikiliq-dataset")

data_beer = pd.read_csv(os.path.join(dataset_path, "beer_data.csv"), index_col=0)
data_spirits = pd.read_csv(os.path.join(dataset_path, "spirits_data.csv"), index_col=0)
data_wine = pd.read_csv(os.path.join(dataset_path, "wine_data.csv"),index_col=0)

# %%
data_beer
# Out:
#                                             Name        Country  \
# 0                    Pipeworks Ninja vs. Unicorn  United States
# 1                          Pipeworks Lizard King  United States
# 2                 Pipeworks Blood Of The Unicorn  United States
# 3                         Pipeworks Brief Relief  United States
# 4                 Pipeworks Sangremancer Red Ale  United States
# ...                                          ...            ...
# 13500  Swirl Sparkling Flavors Unicorn Malt Beer  United States
# 13501               Klockow Schonfeld Honey Beer  United States
# 13502     Blue Norther Prickly Pear Hard Seltzer  United States
# 13503                    Old Bakery Cerveza Lima  United States
# 13504     United Brands Joose Dragon Malt Liquor  United States
#
#                            Brand                                  Categories  \
# 0      Pipeworks Brewing Company              ALE, Imperial  Double IPA, IPA
# ...

# %%
data_spirits
# Out:
#                                                     Name        Country  \
# 0                            Dekuyper Triple Sec Liqueur  United States
# 1                    DeKuyper Peachtree Schnapps Liqueur  United States
# 2            DeKuyper Sour Apple Pucker Schnapps Liqueur  United States
# 3                          DeKuyper Blue Curacao Liqueur  United States
# 4                  DeKuyper Buttershots Schnapps Liqueur  United States
# ...                                                  ...            ...
# 12864                  Crave Chocolate Chili Liqueur 30°  United States
# 12865                                     Roiano Liquore          Italy
# 12866  Very Special Chocolates Classic Assortment Liq...  United States
# 12867                    Whitmeyer’s Texas Peach Whiskey  United States
# 12868                            Don Felix Anejo Tequila         Mexico
#
#                          Brand                           Categories  \
# ...

# %%
data_wine
# Out:
#                                                Name        Country  \
# 0      Block 779 Cabernet Sauvignon Special Reserve  United States
# 1            Block 1015 Cabernet Sauvignon Oakville  United States
# 2                               Block 425 Zinfandel  United States
# 3                      Block 068 Old Vine Zinfandel  United States
# 4                      Block 044 Old Vine Zinfandel  United States
# ...                                             ...            ...
# 26094                                Alto Lima Rosé          Spain
# 26095                             Angel Affair Rosé         France
# 26096           Accademia dei Racemi Burlesque Rose          Italy
# 26097                               Rowen Red Blend  United States
# 26098                     Centorri Moscato Di Pavia          Italy
#
#                        Brand                    Categories Tasting Notes  \
# 0      Vineyard Block Estate  Cabernet Sauvignon, Red Wine           NaN
# ...
